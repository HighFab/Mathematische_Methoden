# %% [markdown]
# # Math. Methoden der Data Science
# __Prof. Dr. Fabian Transchel__
# ### Übung: Selbsteinschätzungstest - Lösung
#
# <hr />

# %% [markdown]
# <ol>
#         <li>Berechnen Sie folgende Werte:<br><br>
#          <ol>
#              <li>$\text{log}_2(32) = 5$<br><br></li>
#              <li>$\text{log}_4(64) = 3$<br><br></li>
#              <li>$\text{ln}(e^2) = 2$<br><br></li>
#              <li>$2^{-2} = \frac{1}{4}$<br><br></li>
#              <li>$64^{\frac{1}{4}}=2.8284271247461903$<br><br></li>
#              <li>$\frac{11!}{3!8!}=165$<br><br></li>
#              <li>$\sum_{k=1}^4 k^2=30$<br><br></li>
#          </ol>
#         </li>
#         <li>Sind die folgenden Ausdrücke korrekt (wahr)? Nennen Sie die relevanten Rechenregeln.
#          <ol>
#              <li>$\text{log}_6(5y) = \text{log}_6(5) + \text{log}_6(y)$<br><br>Wahre Aussage, da $\text{log}_b (x\cdot y) = \text{log}_b x + \text{log}_b y$ gilt.<br><br></li>
#              <li>$\text{log}_7(\frac{y}{x}) = \text{log}_7(y) - \text{log}_7(x)$<br><br>Wahre Aussage, da $\text{log}_b (\frac{x}{y}) = \text{log}_b x - \text{log}_b y$ gilt.<br><br></li>
#              <li>$4\cdot \text{log}_5(2) = \text{log}_5(16)$<br><br>Wahre Aussage, da $ \text{log}_b a^n = n \cdot \text{log}_b a  $ gilt.<br><br></li>
#          </ol>
#         </li>
#         <li>Betrachten Sie eine Menge von fünf paarweise verschiedene Kugeln, die mit den Ziffern $1$ bis $5$ beschriftet seien. Wie viele verschiedene Möglichkeiten der Anordnung gibt es...
#             <ol>
#                 <li>dafür, dass 2 und 3 aufeinander folgen?<br><br>Es gibt 24 verschiedene Möglichkeiten, und zwar $4 \cdot {4\choose 2}$<br><br></li>
#                 <li>dafür, dass 4 vor 2 steht?<br><br>Dies ist im Grunde die gleiche Situation, nur anders ausgedrückt und mit der Kombination 4-2 statt 2-3, alsom gibt es auch hier 24 Kombinationen.<br><br></li>
#                 <li>dafür, dass 1 vor 3, sowie 2 vor 4 steht?<br><br>Es gibt 6 Kombinationen, und zwar $ {2\choose 1} \cdot {3\choose 2}$<br><br></li>
#                 <li>dafür, dass 5 nicht an letzter Stelle steht?<br><br>Die Anzahl der Möglichen Anordnungen ist $96$, dabei ist zu berechnen, dass es $5!$ Kombinationen für die %5% Kugeln gibt, wovon all jene abgezogen werden müssen, die die $5$ an der letzten Stelle haben, also rechnet man $1 \cdot 2 \cdot 3 \cdot 4 \cdot (5-1) = 96$.<br><br></li>
#             </ol>
#         </li>
#         <li>
#             Wie viele Möglichkeiten für Kfz-Kennzeichen im Landkreis Harz gibt es, wenn nur das Kürzel <b>HZ</b> (anstatt WR, QLB etc.) erlaubt ist und der Bezeichner nach dem Strich zwei beliebige Buchstaben außer <i>X</i> und vier beliebige Ziffern außer <i>7</i> enthalten darf?<br><br>Es gibt im Alphabet 26 Buchstaben, davon ist einer (X) gesperrt, also sind $25$ zulässig. Es gibt also $25^2$ Kombinationen von Buchstaben. Für die Ziffern danach gibt es $(10-1)^4$ Kobinationsmöglichkeiten ohne die $7$. Insgesamt ergibt sich so die Zahl von $25^2 \cdot 9^4 = 4.100.625$ möglichen Kombinationen - deutlich mehr als es im Landkreis Harz Fahrzeuge gibt.<br><br>
#         </li>
#         <li>
#             Wenn Sie sechs Mal eine faire Münze (gleiche Wahrscheinlichkeit für Kopf oder Zahl) werfen, wie hoch ist die Wahrscheinlichkeit gerade sechs mal Kopf zu erhalten?<br><br>Man berechnet die Wahrscheinlichkeit zu $(0.5)^6 = 0,015625$<br><br>
#         </li>
#         <li>
#             Betrachten Sie einen sechsseitigen und von 1 bis 6 nummerierten Würfel mit gleicher Wahrscheinlichkeit für jede der Seiten des Würfels. Wie hoch ist die Wahrscheinlichkeit, eine sechs zu würfeln, nachdem Sie bereits eine sechs gewürfelt haben?<br><br>Die Wahrscheinlichkeit ist für jeden Wurf unabhängig von allen anderen Würfen, also $p_{W6}(6) = \frac{1}{6}$.<br><br>
#         </li>
#         <li>
#             Wie hoch ist die Wahrscheinlichkeit, viermal hintereinander eine sechs zu würfeln?<br><br>Die Wahrscheinlichkeit berechnet sich analog zu 5. als $\frac{1}{6}^4 = 7,7160e-4$.<br><br>
#         </li>
#             <li>Gehen Sie davon aus, dass Folgendes zutrifft: 1% der Bürger haben bereits eine Covid-19-Infektion gehabt. Es gibt nun einen Antikörpertest, der dies auch lange Zeit später nachzuweisen sucht.<br><br>
#                 <ul>
#                     <li>90% an durchgeführten Tests erkennen diesen Umstand (true positives)</li>
#                     <li>9.6% der durchgeführten Test liefern ein positives Ergebnis, obwohl keine Infektion vorliegt (false positives)</li></ul>
#                     Wie hoch ist die Wahrscheinlichkeit, dass eine Person ein positives Testergebnis erhält, obwohl Sie in Wahrheit keine Infektion durchgemacht hat? Betrachten Sie eine Grundgesamtheit von 82 Millionen.
#                 <br><br>
#                     Für die einzelne Person liegt folgender Fall vor: Entweder es wurde eine Infektion durchgemacht (1% W-keit) oder nicht (99% W-keit). Wir betrachten nur den Fall, dass keine Infektion vorlag, aber dennoch ein positives Testergebnis. Dies ist aus den Anfangsdaten bereits ermittelbar: Die Wahrscheinlichkeit für <i>false positive</i> ist $9.6$%.<br><br>
#                     Welche Zahlen ergeben sich für die Grundgesamtheit von 82 Millionen? Hierfür ist also zu bestimmen die Rate der (<i>true negatives</i>) und der (<i>false negatives</i>). Diese müssen in Summe wegen $\text{TP} + \text{TN} + \text{FP} + \text{FN} = 1$ gerade $1 - 0.9 - 0.096 = 0.004$ betragen. Die a-priorische Aufteilung ist empirisch nicht zugänglich, da die <i>ground truth</i> nicht vorliegt. Wir betrachten also:<br><br>
#                     $1$% von $82.000.000$: $820.000$<br>
#                     $99$% von $82.000.000$: $81.180.000$<br><br>
#                     Für die Betrachtung der Testergebnisse sind die Gruppen getrennt zu betrachten: Für die erste Gruppe ist bekannt, dass die Genauigkeit $90$% beträgt: Wir erhalten $820.000 \cdot 0.9 = 738.000$ (true) positive Befunde und $82.000$ (falsch) negative Befunde. Für die zweite Gruppe ergibt sich aufgrund der bekannten Fehllerrate von $9.6$% folgendes Bild: $81.180.00 \cdot 0.096 = 7.787.520$ Personen erhalten ein (falsch) positives Ergebnis. Dem gegenüber stehen $73.332.480$ Personen, deren Ergebnis korrekt ist.<br><br>
#                     Zusammengefasst ist war es (zum beschriebenen Zeitpunkt) nicht nur sinnlos, sondern kontrainduktiv, die gesamte Bevölkerung einem solchen Test zu unterziehen, da die Anzahl der falschlicherweise als ehemals infiziert "erkannten" Personen um den Faktor 10 Größer ist als die Gruppe der (true) positiv erkannten. Eine Beschränkung auf solche Personen, wo eine Infektion plausibel erscheint, ist zwar unter praktischen Erwägungen machbar, aber empirisch voreingenommen und kann keine zuverlässigen Ergebnisse liefern.<br><br>
#                     Dies gilt natürlich genau nach Eintritt in die endemische Phase (~2023) der Verbreitung des Virus analog für flächendeckende PCR-Tests, die aktive Infektionen messen sollten.<br><br>
#         <li>
#             Angenommen, das Gewicht von Einjährigen ist normalverteilt mit einem Mittelwert von 9,5kg und einer Standardabweichung von 1,1kg. Sind folgende Aussagen richtig oder falsch (ohne Verwendung eines Taschenrechners):
#             <ol>
#                 <li>Nicht mehr als 20% der Einjährigen sollte ein Gewicht von weniger als 8,4 kg haben<br><br>Die Aussage der Standardabweichung einer Normalverteilung mit $\mathcal{N}(\mu = 9.5,\sigma = 1.1)$ ist unter anderem, dass $68.27$% aller Messwerte innerhalb von $[8.4,10.6]$ zu finden sind. Damit liegen nur $15.865$% der Werte unterhalb $8.4$ kg und die Aussage ist somit korrekt.<br><br></li>
#                 <li>95% der Einjährigen haben ein Gewicht zwischen 7,3 kg und 11,7 kg<br><br>Analog liegen $95.45$% aller Werte im Intervall der zweifachen Standardabweichung $[\mu -2 \sigma, \mu + 2 \sigma]$, also ist auch diese Aussage korrekt.<br><br></li>
#                 <li>3% der Einjährigen haben ein Gewicht von mehr als 12,8 kg<br><br>Diese Aussage ist falsch, da innerhalb der $2\sigma$-Umgebung bereits $95.45$% aller Werte liegen und sich mit der Symmetrieeigenschaft ergibt, dass lediglich $0.5 \cdot (1-0.9545) = 0.02275$, also $2.275$% der Kinder schwerer sind.<br><br></li>
#                 Es ist hierbei zu beachten, dass dies für eine idealisiert unendliche Anzahl an Beobachtungen, mithin nur hinreichend große Menge an Beobachtungen gilt. Für diskrete Messwerte können andere Häufigkeiten vorliegen. Es ist also zu unterscheiden zwischen dem Erwartungswert der Häufigkeit und der Wahrscheinlichkeit, dass dieser auch näherungsweise eintritt. (Formal ist dies für endlich viele Beobachtungen nie der Fall!)<br><br>
#             </ol>
#         </li>
#         <li>Berechnen Sie die Ableitung folgender Funktionen:<br><br>
#             <ol>
#                 <li>$f(x) = 20x^5 \Rightarrow f'(x) = 100x^4$<br><br></li>
#                 <li>$g(y) = 4z^3 + 2z^2 \Rightarrow g'(y) = 0$<br><br></li>
#                 <li>$h(\varepsilon) = 7\varepsilon + 10 \Rightarrow h'(\varepsilon) = 7$<br><br></li>
#                 <li>$i(\theta) = 4\,\theta ^5 + 2\sqrt{\theta} + \frac{3}{\phi} + 2 \Rightarrow i'(\theta) = 20\, \theta ^4 + \frac{1}{\sqrt{\theta}}$<br><br></li>
#                 <li>$\pi(x) = \text{ln}(4+2x^2) \Rightarrow \pi '(x) = \frac{1}{4+2x^2}\cdot 4x$<br><br></li>
#             </ol>
#     </li>
#     <li>Berechnen Sie den euklidischen Abstand der Vektoren $\vec {a} = (3, −2, 5)$ und $\vec{b} = (2,2,3)$. Berechnen Sie außerdem den Abstand in der $1-\text{Norm} \quad d(a,b) = \sum_i |a_i - b_i|$.<br><br>
#     Der Abstand $d(\vec{a},\vec{b})_2$ beträgt offensichtlich $\sqrt{1+4^2+2^2} = \sqrt{21}$. Der Abstand in der <i>1-Norm</i> ist $d(\vec{a},\vec{b})_1 = 7$.<br><br></li>
#     <li>Was ist ein Einheitsvektor? Wie lautet der Einheitsvektor von $(1,2,3)$?<br><br>
#     Der Einheitsvektor $\vec{a}_{\mathbb{1}}$ zu einem Vektor $\vec{a}$ ist derjenige Vektor der Länge $1$, der in Richtung von $\vec{a}$ zeigt: $\vec{a} = a \cdot \vec{a}_{\mathbb{1}}$. Wir erhalten den Einheitsvektor durch Normierung eines Vektors, also Dividieren der Komponenten durch die Länge des Vektors: $\vec{a}_{\mathbb{1}} = \frac{\vec{a}}{|\vec{a}|}$.<br><br>Für den Vektor $(1,2,3)$ ergibt sich $|(1,2,3)| = \sqrt{14} \Rightarrow (1,2,3)_{\mathbb{1}} = \frac{1}{\sqrt{14}} \cdot (1,2,3)$.<br><br></li>
#     <li>Sind $\vec{a}$ und $\vec{b}$ orthogonal zueinander? Falls nein, wie ist der Winkel?<br><br>Das Skalarprodukt von $\vec{a}$ mit $\vec{b}$ ist $\vec{a}\cdot \vec{b} = 3 \cdot 2 - 2 \cdot 2 + 5 \cdot 3$ = 17, die Vektoren sind also nicht orthogonal, da hierfür das Skalarprodukt verschwinden müsste. Der Winkel lässt sich berechnen zu $\alpha = \text{cos}^{-1}\frac{\vec{a}\cdot\vec{b}}{|\vec{a}|\cdot|{b}|} = 48,021$°.<br><br></li>
#     <li>Sei $A = \begin{pmatrix} 1 & 0 \\ -1 & 1 \end{pmatrix}$ eine Matrix. Berechnen Sie:
#         <ol>
#             <li>Den Rang von $A$<br><br>$\text{Rg}A = 2$<br><br></li>
#             <li>Die Determinante von $A$<br><br>$\text{det}A = 2$<br><br></li>
#             <li>Die Spur von $A$<br><br>$\text{Sp}A = 2$<br><br></li>
#             <li>Die Norm von $A$<br><br>$|A| = \sqrt{3}$<br><br></li>
#         </ol>
#     </li>
#     <li>Sind die Spalten von $A$ linear unabhängig?<br><br>Ja, da $(1,-1) \cdot (0,1) = -1 \neq 0$<br><br></li>
#     <li>Was ist eine Orthogonale Matrix?<br><br>Eine Matrix $M$, deren Produkt mit ihrer Transponierten $M^T$ die Einheitsmatrix ergibt: $M \cdot M^T = \mathbb{1}$. Um dies zu erfüllen muss gelten, dass Zeilen- oder Spaltenvektoren paarweise orthogonal sind und zusätzlich normiert sind, also die Länge eins aufweisen. Man nennt solche Matrizen auch <i>stochastisch</i>, da sie Wahrscheinlichkeitstreue Abbildungen definieren, wie wir später sehen werden.<br><br></li>
#     <li>Bestimmen Sie die Normierte $A'$ von $A$, sodass $||A'|| = 1$.<br><br>Da der Betrag von $A$ gerade $\sqrt{3}$ ist, ergibt sich $A' = \frac{1}{\sqrt{3}}\begin{pmatrix} 1 & 0 \\ -1 & 1 \end{pmatrix}$.<br><br></li>
#     <li>Ist $A$ invertierbar? Falls ja, bestimmen Sie $A^{-1}$.<br><br>Mit dem Gauss-verfahren erhält man $A^{-1} = np.array([[1,0],[1,1]])$. Wir werden später sehen, dass sich dies numerisch mit Hilfe der Singulärwertzerlegung verallgemeinern lässt.<br><br></li>
#     <li>Was ist der Unterschied zwischen dem arithmetischen Mittelwert, dem Median und dem Modus?<br><br>Allen Größen ist gemein, dass sie ein "zentrales Moment" einer Menge von Punkten bzw. Beobachtungen darstellen. Konkret liegt der Unterschied in der Definition:<ul><li>Arithmetischer Mittelwert: $\bar{x}_\text{arithm.}\frac{1}{n}\sum_{i=1}^nx_i$</li><li>Median: Entspricht exakt dem 50%-Quantil $Q(\frac{1}{2})$, d.h. dass die Hälfte aller Beobachtungen kleiner und die Hälfte aller Beobachtungen größer sind.</li><li>Modus: Der Häufigste Wert einer Stichprobe.</li></ul><br><br></li>
#     <li>Was ist der Unterschied zwischen der Varianz und der Standardabweichung?<br><br>Die Varianz ist ein Maß für die Streuung der Wahrscheinlichkeitsdichte um ihren Schwerpunkt. Die Standardabweichung ist die Quadratwurzel dieses Maßes und hat für symmetrische Verteilungen wie die Normalverteilung nützliche(re) Eigenschaften.<br><br></li>
#     <li>Was versteht man unter nominal-, ordinal- und intervallskalierten Daten? Versuchen Sie für jeden Typ ein Beispiel zu finden.<br><br><ul><li>Nominalskaliert: Kategorieller Datentyp, bei dem es <i>keine</i> Ordnungsrelation, bzw. Norm auf den Daten gibt. Beispiel: Kugeln der Farben rot, grün und blau.</li><li>Ordinalskaliert: Nominalskalierte Variablen mit einer Ordnungsrelation - Ausprägungen können der "Größe" nach Sortiert werden. Beispiel: Zylinderangabe für Motorentypen.</li><li>Intervallskaliert: Innerhalb eines definiten Wertebereichs kontinuierliche Skala. Beispiel: Temperatur einer Wetterstation.</li></ul><br><br></li>
#     <li>Was versteht man unter einem Ausreißer?<br><br>Ein Wert einer Messreihe bzw. Zufallsvariable, der außerhalb des von der (ggf. nur vermuteten) Verteilung Bereiches liegt; typischerweise werden Werte außerhalb des 1,5-Fachen des Quartilabstandes als Ausreißer bezeichnet<br><br></li>
#     <li>Was ist der Unterschied zwischen einem Histogramm und einem Kerndichteschätzer?<br><br>Ein Histogramm stellt die Häufigkeitsverteilung auf diskreten, quantil-sortierten Bins dar, ein Kerndichteschätzer gibt die (infinitesimale) Häufigkeitsdichte als kontinuierliches Spektrum an.<br><br></li>
# </ol>
#
# <b>Einordnung der Ergebnisse</b>
#
# Unter Berücksichtigung der zulassungsfähigen Vorkenntnisse des Studiengangs wird davon ausgegangen, dass mehr als 75% der Fragen beantwortet werden können; die Bearbeitungszeit wird hierbei auf etwa zwei bis drei Stunden geschätzt, spielt aber für sich genommen keine Rolle. Wenn sich bereichsweise Defizite zeigen ist zu prüfen, ob diese auf einzelne, möglicherweise unterschlagene oder ausgelassene Vorkenntnisse zurückzuführen sind. Bei mehr als 50% unvollständigen Antworten ist dringend angeraten, die bestehenden Defizite in Bezug auf die Bachelor-Vorkenntnisse in einer Sprechstunde mit dem Dozenten und/oder dem Studiengangskoordinator zu erörtern.
