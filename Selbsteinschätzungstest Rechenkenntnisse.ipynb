# %% [markdown]
# # Math. Methoden der Data Science
# __Prof. Dr. Fabian Transchel__
# ### Übung: Selbsteinschätzungstest
#
# <hr />
#
# <div class="alert alert-block alert-warning">
#     Führen Sie die Übung vorzugsweise ohne Taschenrechner aus.
#     </div>
#
# <ol>
#         <li>Berechnen Sie folgende Werte:
#          <ol>
#              <li>$\text{log}_2(32) = $&nbsp;?</li>
#              <li>$\text{log}_4(64) = $&nbsp;?</li>
#              <li>$\text{ln}(e^2) = $&nbsp;?</li>
#              <li>$2^{-2} = $&nbsp;?</li>
#              <li>$64^{\frac{1}{4}}=$&nbsp;?</li>
#              <li>$\frac{11!}{3!8!}=$&nbsp;?</li>
#              <li>$\sum_{k=1}^4 k^2=$&nbsp;?</li>
#          </ol>
#         </li>
#         <li>Sind die folgenden Ausdrücke korrekt (wahr)? Nennen Sie die relevanten Rechenregeln.
#          <ol>
#              <li>$\text{log}_6(5y) = \text{log}_6(5) + \text{log}_6(y)$</li>
#              <li>$\text{log}_7(\frac{y}{x}) = \text{log}_7(y) - \text{log}_7(x)$</li>
#              <li>$4\cdot \text{log}_5(2) = \text{log}_5(16)$</li>
#          </ol>
#         </li>
#         <li>Betrachten Sie eine Menge von fünf paarweise verschiedene Kugeln, die mit den Ziffern $1$ bis $5$ beschriftet seien. Wie viele verschiedene Möglichkeiten der Anordnung gibt es...
#             <ol>
#                 <li>dafür, dass 2 und 3 aufeinander folgen?</li>
#                 <li>dafür, dass 4 vor 2 steht?</li>
#                 <li>dafür, dass 1 vor 3, sowie 2 vor 4 steht?</li>
#                 <li>dafür, dass 5 nicht an letzter Stelle steht?</li>
#             </ol>
#         </li>
#         <li>
#             Wie viele Möglichkeiten für Kfz-Kennzeichen im Landkreis Harz gibt es, wenn nur das Kürzel <b>HZ</b> (anstatt WR, QLB etc.) erlaubt ist und der Bezeichner nach dem Strich zwei beliebige Buchstaben außer <i>X</i> und vier beliebige Ziffern außer <i>7</i> enthalten darf?
#         </li>
#         <li>
#             Wenn Sie sechs Mal eine faire Münze (gleiche Wahrscheinlichkeit für Kopf oder Zahl) werfen, wie hoch ist die Wahrscheinlichkeit gerade sechs mal Kopf zu erhalten?
#         </li>
#         <li>
#             Betrachten Sie einen sechsseitigen und von 1 bis 6 nummerierten Würfel mit gleicher Wahrscheinlichkeit für jede der Seiten des Würfels. Wie hoch ist die Wahrscheinlichkeit, eine sechs zu würfeln, nachdem Sie bereits eine sechs gewürfelt haben?
#         </li>
#         <li>
#             Wie hoch ist die Wahrscheinlichkeit, viermal hintereinander eine sechs zu würfeln?
#         </li>
#             Gehen Sie davon aus, dass Folgendes zutrifft: 1% der Bürger haben bereits eine Covid-19-Infektion gehabt. Es gibt nun einen Antikörpertest, der dies auch lange Zeit später nachzuweisen sucht.
#             - 90% an durchgeführten Tests erkennen diesen Umstand (true positives)
#             - 9.6% der durchgeführten Test liefern ein positives Ergebnis, obwohl keine Infektion vorliegt (false positives)
#             Wie hoch ist die Wahrscheinlichkeit, dass eine Person ein positives Testergebnis erhält, obwohl Sie in Wahrheit keine Infektion durchgemacht hat? Betrachten Sie eine Grundgesamtheit von 82 Millionen.
#         <li>
#             Angenommen, das Gewicht von Einjährigen ist normalverteilt mit einem Mittelwert von 9,5kg und einer Standardabweichung von 1,1kg. Sind folgende Aussagen richtig oder falsch (ohne Verwendung eines Taschenrechners):
#             <ol>
#                 <li>Nicht mehr als 20% der Einjährigen sollte ein Gewicht von weniger als 8,4 kg haben</li>
#                 <li>95% der Einjährigen haben ein Gewicht zwischen 7,3 kg und 11,7 kg</li>
#                 <li>3% der Einjährigen haben ein Gewicht von mehr als 12,8 kg</li>
#             </ol>
#         </li>
#         <li>Berechnen Sie die Ableitung folgender Funktionen:
#             <ol>
#                 <li>$f(x) = 20x^5$</li>
#                 <li>$g(y) = 4z^3 + 2z^2$</li>
#                 <li>$h(\varepsilon) = 7\varepsilon + 10$</li>
#                 <li>$i(\theta) = 4\theta ^5 + 2\sqrt{\theta} + \frac{3}{\phi} + 2$</li>
#                 <li>$\pi(x) = \text{ln}(4+2x^2)$</li>
#             </ol>
#     </li>
#     <li>Berechnen Sie den euklidischen Abstand der Vektoren $\vec {a} = (3, −2, 5)$ und $\vec{b} = (2,2,3)$. Berechnen Sie außerdem den Abstand in der $1-\text{Norm} \quad d(a,b) = \sum_i |a_i - b_i|$.</li>
#     <li>Was ist ein Einheitsvektor? Wie lautet der Einheitsvektor von $(1,2,3)$?</li>
#     <li>Sind $\vec{a}$ und $\vec{b}$ orthogonal zueinander? Falls nein, wie ist der Winkel?</li>
#     <li>Sei $A = \begin{pmatrix} 1 & 0 \\ -1 & 1 \end{pmatrix}$ eine Matrix. Berechnen Sie:
#         <ol>
#             <li>Den Rang von $A$</li>
#             <li>Die Determinante von $A$</li>
#             <li>Die Spur von $A$</li>
#             <li>Die Norm von $A$</li>
#         </ol>
#     </li>
#     <li>Sind die Spalten von $A$ linear unabhängig?</li>
#     <li>Was ist eine Orthogonale Matrix?</li>
#     <li>Bestimmen Sie die Normierte $A'$ von $A$, sodass $||A'|| = 1$.
#     <li>Ist $A$ invertierbar? Falls ja, bestimmen Sie $A^{-1}$.
#     <li>Was ist der Unterschied zwischen dem arithmetischen Mittelwert, dem Median und dem Modus?</li>
#     <li>Was ist der Unterschied zwischen der Varianz und der Standardabweichung?</li>
#     <li>Was versteht man unter nominal-, ordinal- und intervallskalierten Daten? Versuchen Sie für jeden Typ ein Beispiel zu finden.</li>
#     <li>Was versteht man unter einem Ausreißer?</li>
#     <li>Was ist der Unterschied zwischen einem Histogramm und einem Kerndichteschätzer? </li>
# </ol>
